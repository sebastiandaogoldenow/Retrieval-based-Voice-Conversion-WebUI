# %% [markdown]
# # RVC-RMVPE 🐳
# ## (No WEB UI) RUSSIA
#
# **Загрузка датасета:**
# Input - <название датасета> - внутри сразу wav файлы (без подпапок)
#
# **Запуск в фоновом режиме:**
# Save Versions - Save Output - Always Save Output... - SAVE и ждем начало тренировки!
#
# **Где лежит модель?:**
# В папке Output в .zip архиве

# %% [markdown]
# # Install dependencies and download pretrained model

# %%
# Установка необходимых зависимостей
# !apt-get -y install build-essential python3-dev ffmpeg
# !pip3 install --upgrade setuptools wheel
# !pip3 install --upgrade pip
# !pip3 install faiss-cpu==1.7.2 fairseq gradio==3.14.0 ffmpeg ffmpeg-python praat-parselmouth pyworld numpy==1.23.5 numba==0.56.4 librosa==0.9.2
# !pip3 install torch torchvision torchaudio

# Создание каталогов для рабочей среды
# !mkdir content
# !mkdir content/rmvpe-ai
# %cd /kaggle/working/content/rmvpe-ai

# Клонирование репозитория rmvpe-ai с выбранным веткой 'v1.1-patch-no-ui'
# !git clone -b 'v1.1-patch-no-ui' --single-branch --depth 1 https://github.com/elcolex777/rmvpe-ai.git .

# Установка зависимостей из requirements.txt
# !pip install -r requirements.txt

# Установка aria2 для управления загрузками
# !sudo apt-get update
# !apt -y install -qq aria2
# Out:
# build-essential is already the newest version (12.8ubuntu1.1).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# The following additional packages will be installed:
#   libexpat1-dev libpython3-dev libpython3.8-dev python3.8-dev
# The following NEW packages will be installed:
#   libexpat1-dev libpython3-dev libpython3.8-dev python3-dev python3.8-dev
# 0 upgraded, 5 newly installed, 0 to remove and 51 not upgraded.
# Need to get 4589 kB of archives.
# After this operation, 21.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libexpat1-dev amd64 2.2.9-1ubuntu0.6 [116 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpython3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [3950 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libpython3-dev amd64 3.8.2-0ubuntu2 [7236 B]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3.8-dev amd64 3.8.10-0ubuntu1~20.04.9 [514 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-dev amd64 3.8.2-0ubuntu2 [1212 B]
# Fetched 4589 kB in 1s (3408 kB/s)
# Selecting previously unselected package libexpat1-dev:amd64.
# (Reading database ... 113807 files and directories currently installed.)
# Preparing to unpack .../libexpat1-dev_2.2.9-1ubuntu0.6_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Selecting previously unselected package libpython3.8-dev:amd64.
# Preparing to unpack .../libpython3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...
# Unpacking libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...
# Selecting previously unselected package libpython3-dev:amd64.
# Preparing to unpack .../libpython3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python3.8-dev.
# Preparing to unpack .../python3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb ...
# Unpacking python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../python3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking python3-dev (3.8.2-0ubuntu2) ...
# Setting up libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Setting up libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.9) ...
# Setting up python3.8-dev (3.8.10-0ubuntu1~20.04.9) ...
# Setting up libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Setting up python3-dev (3.8.2-0ubuntu2) ...
# Processing triggers for man-db (2.9.1-1) ...
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (69.0.3)
# Collecting setuptools
#   Downloading setuptools-69.2.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (0.42.0)
# Collecting wheel
#   Downloading wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# Downloading setuptools-69.2.0-py3-none-any.whl (821 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.5/821.5 kB 2.3 MB/s eta 0:00:00
# Downloading wheel-0.43.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: wheel, setuptools
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.42.0
#     Uninstalling wheel-0.42.0:
#       Successfully uninstalled wheel-0.42.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.0.3
#     Uninstalling setuptools-69.0.3:
#       Successfully uninstalled setuptools-69.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# Successfully installed setuptools-69.2.0 wheel-0.43.0
# Requirement already satisfied: pip in /opt/conda/lib/python3.10/site-packages (23.3.2)
# Collecting pip
#   Downloading pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.2
#     Uninstalling pip-23.3.2:
#       Successfully uninstalled pip-23.3.2
# Successfully installed pip-24.0
# Collecting faiss-cpu==1.7.2
#   Downloading faiss_cpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting fairseq
#   Downloading fairseq-0.12.2.tar.gz (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 28.5 MB/s eta 0:00:00
# done
#   Getting requirements to build wheel ... done
# done
# done
# Collecting gradio==3.14.0
#   Downloading gradio-3.14.0-py3-none-any.whl.metadata (13 kB)
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
# done
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting praat-parselmouth
#   Downloading praat_parselmouth-0.4.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.8 kB)
# Collecting pyworld
#   Downloading pyworld-0.3.4.tar.gz (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.0/252.0 kB 15.3 MB/s eta 0:00:00
# done
#   Getting requirements to build wheel ... done
# done
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting numba==0.56.4
#   Downloading numba-0.56.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting librosa==0.9.2
#   Downloading librosa-0.9.2-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (3.9.1)
# Requirement already satisfied: altair in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (5.2.0)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (0.108.0)
# Collecting ffmpy (from gradio==3.14.0)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
# done
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (2024.3.0)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (0.27.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (3.1.2)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (3.0.0)
# Requirement already satisfied: markupsafe in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (2.1.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (3.7.5)
# Requirement already satisfied: orjson in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (3.9.10)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (2.1.4)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (9.5.0)
# Requirement already satisfied: pycryptodome in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (3.20.0)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (2.5.3)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (0.25.1)
# Collecting python-multipart (from gradio==3.14.0)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (2.31.0)
# Requirement already satisfied: uvicorn in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (0.25.0)
# Requirement already satisfied: websockets>=10.0 in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0) (12.0)
# Collecting llvmlite<0.40,>=0.39.0dev0 (from numba==0.56.4)
#   Downloading llvmlite-0.39.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from numba==0.56.4) (69.2.0)
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.2) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.2) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.19.1 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.2) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.2) (1.3.2)
# Requirement already satisfied: decorator>=4.0.10 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.2) (5.1.1)
# Collecting resampy>=0.2.2 (from librosa==0.9.2)
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: soundfile>=0.10.2 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.2) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.2) (1.8.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.2) (21.3)
# Requirement already satisfied: cffi in /opt/conda/lib/python3.10/site-packages (from fairseq) (1.16.0)
# Requirement already satisfied: cython in /opt/conda/lib/python3.10/site-packages (from fairseq) (3.0.8)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from fairseq) (2023.12.25)
# Collecting sacrebleu>=1.4.12 (from fairseq)
#   Downloading sacrebleu-2.4.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from fairseq) (2.1.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from fairseq) (4.66.1)
# Collecting bitarray (from fairseq)
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: torchaudio>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from fairseq) (2.1.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from ffmpeg-python) (1.0.0)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 6.1 MB/s eta 0:00:00
# done
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->librosa==0.9.2) (3.1.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa==0.9.2) (4.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->gradio==3.14.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->gradio==3.14.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->gradio==3.14.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->gradio==3.14.0) (2024.2.2)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq)
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq) (0.9.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq) (5.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.19.1->librosa==0.9.2) (3.2.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi->fairseq) (2.21)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0) (4.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair->gradio==3.14.0) (4.20.0)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair->gradio==3.14.0) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->gradio==3.14.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->gradio==3.14.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->gradio==3.14.0) (2023.4)
# Requirement already satisfied: starlette<0.33.0,>=0.29.0 in /opt/conda/lib/python3.10/site-packages (from fastapi->gradio==3.14.0) (0.32.0.post1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic->gradio==3.14.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic->gradio==3.14.0) (2.14.6)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx->gradio==3.14.0) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx->gradio==3.14.0) (1.0.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->gradio==3.14.0) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx->gradio==3.14.0) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio==3.14.0) (0.1.2)
# Requirement already satisfied: mdit-py-plugins in /opt/conda/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio==3.14.0) (0.4.0)
# Requirement already satisfied: linkify-it-py<3,>=1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio==3.14.0) (2.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->gradio==3.14.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->gradio==3.14.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->gradio==3.14.0) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->gradio==3.14.0) (1.4.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->fairseq) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->fairseq) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->fairseq) (3.2.1)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn->gradio==3.14.0) (8.1.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair->gradio==3.14.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair->gradio==3.14.0) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair->gradio==3.14.0) (0.16.2)
# Requirement already satisfied: uc-micro-py in /opt/conda/lib/python3.10/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]->gradio==3.14.0) (1.0.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->gradio==3.14.0) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx->gradio==3.14.0) (1.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->fairseq) (1.3.0)
# Downloading faiss_cpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 56.9 MB/s eta 0:00:00
# Downloading gradio-3.14.0-py3-none-any.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 58.5 MB/s eta 0:00:00
# Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 62.2 MB/s eta 0:00:00
# Downloading numba-0.56.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 71.7 MB/s eta 0:00:00
# Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 11.5 MB/s eta 0:00:00
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading praat_parselmouth-0.4.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 72.4 MB/s eta 0:00:00
# Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 5.9 MB/s eta 0:00:00
# Downloading llvmlite-0.39.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 39.5 MB/s eta 0:00:00
# Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 65.8 MB/s eta 0:00:00
# Downloading sacrebleu-2.4.1-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 4.3 MB/s eta 0:00:00
# Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 14.5 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: fairseq, ffmpeg, pyworld, antlr4-python3-runtime, ffmpy
# done
#   Created wheel for fairseq: filename=fairseq-0.12.2-cp310-cp310-linux_x86_64.whl size=10416014 sha256=2a85018a724833116be348e204f8761973ceea2af180028f9f2d1c8ab8698b73
#   Stored in directory: /root/.cache/pip/wheels/e4/35/55/9c66f65ec7c83fd6fbc2b9502a0ac81b2448a1196159dacc32
# done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=cf9a77c17cd3bfc95f3edc42ee100209c38d04f4a5740d0a73f0c4e0daab2903
#   Stored in directory: /root/.cache/pip/wheels/8e/7a/69/cd6aeb83b126a7f04cbe7c9d929028dc52a6e7d525ff56003a
# done
#   Created wheel for pyworld: filename=pyworld-0.3.4-cp310-cp310-linux_x86_64.whl size=221575 sha256=b8a0742afdc53378824415fc375581d109a9242350ae371add4d17c111e8cbdf
#   Stored in directory: /root/.cache/pip/wheels/66/09/8a/a1d79b73d59756f66e9bfe55a199840efc7473adb76ddacdfd
# done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141211 sha256=44cbb043564ff88dda37bc68638371e1a367b6b520e61e718e90b77538f68e91
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=c9d6b4bb054c00eec265d66141d1223013250e0a49f71fc5fbe3cd34cfd73f6d
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built fairseq ffmpeg pyworld antlr4-python3-runtime ffmpy
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: ffmpy, ffmpeg, faiss-cpu, bitarray, antlr4-python3-runtime, python-multipart, portalocker, omegaconf, numpy, llvmlite, ffmpeg-python, sacrebleu, pyworld, praat-parselmouth, numba, hydra-core, resampy, librosa, fairseq, gradio
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.41.1
#     Uninstalling llvmlite-0.41.1:
#       Successfully uninstalled llvmlite-0.41.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.58.1
#     Uninstalling numba-0.58.1:
#       Successfully uninstalled numba-0.58.1
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.1
#     Uninstalling librosa-0.10.1:
#       Successfully uninstalled librosa-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# keras-nlp 0.8.2 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# albumentations 1.4.0 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# chex 0.1.85 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# cudf 23.8.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# cuml 23.8.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# dask-cuda 23.8.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# featuretools 1.30.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.1 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# pyldavis 3.4.1 requires numpy>=1.24.2, but you have numpy 1.23.5 which is incompatible.
# pylibraft 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# raft-dask 23.8.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# rmm 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# rmm 23.8.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# tensorstore 0.1.56 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# woodwork 0.29.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# xarray 2024.2.0 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.8 bitarray-2.9.2 fairseq-0.12.2 faiss-cpu-1.7.2 ffmpeg-1.4 ffmpeg-python-0.2.0 ffmpy-0.3.2 gradio-3.14.0 hydra-core-1.0.7 librosa-0.9.2 llvmlite-0.39.1 numba-0.56.4 numpy-1.23.5 omegaconf-2.0.6 portalocker-2.8.2 praat-parselmouth-0.4.3 python-multipart-0.0.9 pyworld-0.3.4 resampy-0.4.3 sacrebleu-2.4.1
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# /kaggle/working/content/rmvpe-ai
# Cloning into '.'...
# remote: Enumerating objects: 174, done.
# remote: Counting objects: 100% (174/174), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 174 (delta 28), reused 173 (delta 28), pack-reused 0
# Receiving objects: 100% (174/174), 1.19 MiB | 8.84 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# Note: switching to 'd32dd6b2d781df701fd474c39ef54fcc940880c3'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# Requirement already satisfied: joblib>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: numba==0.56.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.56.4)
# Requirement already satisfied: numpy==1.23.5 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.23.5)
# Collecting scipy==1.9.3 (from -r requirements.txt (line 4))
#   Downloading scipy-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 800.9 kB/s eta 0:00:00
# Collecting librosa==0.9.1 (from -r requirements.txt (line 5))
#   Downloading librosa-0.9.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting llvmlite==0.39.0 (from -r requirements.txt (line 6))
#   Downloading llvmlite-0.39.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: fairseq==0.12.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (0.12.2)
# Collecting faiss-cpu==1.7.3 (from -r requirements.txt (line 8))
#   Downloading faiss_cpu-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: gradio==3.14.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (3.14.0)
# Requirement already satisfied: Cython in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (3.0.8)
# Requirement already satisfied: pydub>=0.25.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (0.25.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (0.12.1)
# Requirement already satisfied: ffmpeg-python>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (2.6.2.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: json5 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.9.14)
# Requirement already satisfied: Markdown in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (3.5.2)
# Requirement already satisfied: matplotlib>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (3.7.5)
# Requirement already satisfied: matplotlib-inline>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (0.1.6)
# Requirement already satisfied: praat-parselmouth>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (0.4.3)
# Requirement already satisfied: Pillow>=9.1.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (9.5.0)
# Requirement already satisfied: resampy>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (0.4.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (1.2.2)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (2.15.1)
# Requirement already satisfied: tqdm>=4.63.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (4.66.1)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (6.3.3)
# Requirement already satisfied: Werkzeug>=2.2.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (3.0.1)
# Requirement already satisfied: uc-micro-py>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (1.0.3)
# Requirement already satisfied: sympy>=1.11.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (1.12)
# Requirement already satisfied: tabulate>=0.8.10 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (0.9.0)
# Requirement already satisfied: PyYAML>=6.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (6.0.1)
# Requirement already satisfied: pyasn1>=0.4.8 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (0.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.8 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (0.3.0)
# Requirement already satisfied: fsspec>=2022.11.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 34)) (2024.3.0)
# Requirement already satisfied: absl-py>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (1.4.0)
# Requirement already satisfied: audioread in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (3.0.1)
# Requirement already satisfied: uvicorn>=0.21.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (0.25.0)
# Requirement already satisfied: colorama>=0.4.5 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (0.4.6)
# Collecting pyworld==0.3.2 (from -r requirements.txt (line 39))
#   Downloading pyworld-0.3.2.tar.gz (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 2.0 MB/s eta 0:00:00
# done
# done
# done
# Collecting httpx==0.23.0 (from -r requirements.txt (line 40))
#   Downloading httpx-0.23.0-py3-none-any.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 1.4 MB/s eta 0:00:00
# Collecting torchcrepe==0.0.20 (from -r requirements.txt (line 42))
#   Downloading torchcrepe-0.0.20-py3-none-any.whl.metadata (7.8 kB)
# Collecting fastapi==0.88 (from -r requirements.txt (line 43))
#   Downloading fastapi-0.88.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from numba==0.56.4->-r requirements.txt (line 2)) (69.2.0)
# Requirement already satisfied: decorator>=4.0.10 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.1->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.1->-r requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from librosa==0.9.1->-r requirements.txt (line 5)) (21.3)
# Requirement already satisfied: cffi in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: hydra-core<1.1,>=1.0.7 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 7)) (1.0.7)
# Requirement already satisfied: omegaconf<2.1 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 7)) (2.0.6)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 7)) (2023.12.25)
# Requirement already satisfied: sacrebleu>=1.4.12 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 7)) (2.4.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 7)) (2.1.2)
# Requirement already satisfied: bitarray in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 7)) (2.9.2)
# Requirement already satisfied: torchaudio>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2->-r requirements.txt (line 7)) (2.1.2)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (3.9.1)
# Requirement already satisfied: altair in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (5.2.0)
# Requirement already satisfied: ffmpy in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (0.3.2)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: markupsafe in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (2.1.3)
# Requirement already satisfied: orjson in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (3.9.10)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (2.1.4)
# Requirement already satisfied: pycryptodome in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (3.20.0)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (2.5.3)
# Requirement already satisfied: python-multipart in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (0.0.9)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (2.31.0)
# Requirement already satisfied: websockets>=10.0 in /opt/conda/lib/python3.10/site-packages (from gradio==3.14.0->-r requirements.txt (line 9)) (12.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx==0.23.0->-r requirements.txt (line 40)) (2024.2.2)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx==0.23.0->-r requirements.txt (line 40)) (1.3.0)
# Collecting rfc3986<2,>=1.3 (from rfc3986[idna2008]<2,>=1.3->httpx==0.23.0->-r requirements.txt (line 40))
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore<0.16.0,>=0.15.0 (from httpx==0.23.0->-r requirements.txt (line 40))
#   Downloading httpcore-0.15.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic (from gradio==3.14.0->-r requirements.txt (line 9))
#   Downloading pydantic-1.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.2/150.2 kB 1.7 MB/s eta 0:00:00
# Collecting starlette==0.22.0 (from fastapi==0.88->-r requirements.txt (line 43))
#   Downloading starlette-0.22.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette==0.22.0->fastapi==0.88->-r requirements.txt (line 43)) (4.2.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from ffmpeg-python>=0.2.0->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorboardX->-r requirements.txt (line 14)) (3.20.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 18)) (2.9.0.post0)
# Requirement already satisfied: traitlets in /opt/conda/lib/python3.10/site-packages (from matplotlib-inline>=0.1.3->-r requirements.txt (line 19)) (5.9.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 23)) (3.2.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 24)) (1.51.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 24)) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 24)) (1.2.0)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 24)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->-r requirements.txt (line 24)) (0.7.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy>=1.11.1->-r requirements.txt (line 29)) (1.3.0)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.21.1->-r requirements.txt (line 37)) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.21.1->-r requirements.txt (line 37)) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.21.1->-r requirements.txt (line 37)) (4.9.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi->fairseq==0.12.2->-r requirements.txt (line 7)) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 24)) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 24)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->-r requirements.txt (line 24)) (1.3.1)
# Collecting h11>=0.8 (from uvicorn>=0.21.1->-r requirements.txt (line 37))
#   Downloading h11-0.12.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting anyio<5,>=3.4.0 (from starlette==0.22.0->fastapi==0.88->-r requirements.txt (line 43))
#   Downloading anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi==0.88->-r requirements.txt (line 43)) (3.6)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi==0.88->-r requirements.txt (line 43)) (1.2.0)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /opt/conda/lib/python3.10/site-packages (from hydra-core<1.1,>=1.0.7->fairseq==0.12.2->-r requirements.txt (line 7)) (4.8)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa==0.9.1->-r requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->gradio==3.14.0->-r requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->gradio==3.14.0->-r requirements.txt (line 9)) (1.26.18)
# Requirement already satisfied: portalocker in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2->-r requirements.txt (line 7)) (5.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0->-r requirements.txt (line 9)) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0->-r requirements.txt (line 9)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0->-r requirements.txt (line 9)) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0->-r requirements.txt (line 9)) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0->-r requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->gradio==3.14.0->-r requirements.txt (line 9)) (4.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair->gradio==3.14.0->-r requirements.txt (line 9)) (4.20.0)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair->gradio==3.14.0->-r requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->gradio==3.14.0->-r requirements.txt (line 9)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->gradio==3.14.0->-r requirements.txt (line 9)) (2023.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio==3.14.0->-r requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio==3.14.0->-r requirements.txt (line 9)) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /opt/conda/lib/python3.10/site-packages (from markdown-it-py[linkify,plugins]->gradio==3.14.0->-r requirements.txt (line 9)) (0.4.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->fairseq==0.12.2->-r requirements.txt (line 7)) (3.13.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->fairseq==0.12.2->-r requirements.txt (line 7)) (3.2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair->gradio==3.14.0->-r requirements.txt (line 9)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair->gradio==3.14.0->-r requirements.txt (line 9)) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair->gradio==3.14.0->-r requirements.txt (line 9)) (0.16.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->-r requirements.txt (line 24)) (3.2.2)
# Downloading scipy-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 5.0 MB/s eta 0:00:00
# Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 4.7 MB/s eta 0:00:00
# Downloading llvmlite-0.39.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 7.4 MB/s eta 0:00:00
# Downloading faiss_cpu-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 11.3 MB/s eta 0:00:00
# Downloading httpx-0.23.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 3.9 MB/s eta 0:00:00
# Downloading torchcrepe-0.0.20-py3-none-any.whl (72.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 MB 10.5 MB/s eta 0:00:00
# Downloading fastapi-0.88.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 2.6 MB/s eta 0:00:00
# Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 3.3 MB/s eta 0:00:00
# Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 2.8 MB/s eta 0:00:00
# Downloading anyio-3.7.1-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 4.5 MB/s eta 0:00:00
# Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.8 MB/s eta 0:00:00
# Downloading pydantic-1.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 15.8 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Building wheels for collected packages: pyworld
# done
#   Created wheel for pyworld: filename=pyworld-0.3.2-cp310-cp310-linux_x86_64.whl size=219002 sha256=02a7b5ade7a4318da3652f987ef245a4fefbdcc81228e3d67d4d85d98dfb460d
#   Stored in directory: /root/.cache/pip/wheels/35/48/7e/e25bdd25fda4326d47010c157709436a6ee7a1423e18a24195
# Successfully built pyworld
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: rfc3986, faiss-cpu, scipy, pyworld, pydantic, llvmlite, h11, anyio, starlette, httpcore, httpx, fastapi, librosa, torchcrepe
#   Attempting uninstall: faiss-cpu
#     Found existing installation: faiss-cpu 1.7.2
#     Uninstalling faiss-cpu-1.7.2:
#       Successfully uninstalled faiss-cpu-1.7.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: pyworld
#     Found existing installation: pyworld 0.3.4
#     Uninstalling pyworld-0.3.4:
#       Successfully uninstalled pyworld-0.3.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.2.0
#     Uninstalling anyio-4.2.0:
#       Successfully uninstalled anyio-4.2.0
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.32.0.post1
#     Uninstalling starlette-0.32.0.post1:
#       Successfully uninstalled starlette-0.32.0.post1
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.4
#     Uninstalling httpcore-1.0.4:
#       Successfully uninstalled httpcore-1.0.4
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.108.0
#     Uninstalling fastapi-0.108.0:
#       Successfully uninstalled fastapi-0.108.0
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.9.2
#     Uninstalling librosa-0.9.2:
#       Successfully uninstalled librosa-0.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# albumentations 1.4.0 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.0 requires scipy>=1.10.0, but you have scipy 1.9.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# cuml 23.8.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# featuretools 1.30.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# featuretools 1.30.0 requires scipy>=1.10.0, but you have scipy 1.9.3 which is incompatible.
# jupyterlab 4.1.5 requires httpx>=0.25.0, but you have httpx 0.23.0 which is incompatible.
# jupyterlab 4.1.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# kaggle-environments 1.14.3 requires scipy>=1.11.2, but you have scipy 1.9.3 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pyldavis 3.4.1 requires numpy>=1.24.2, but you have numpy 1.23.5 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# raft-dask 23.8.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# rmm 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# rmm 23.8.0 requires numba>=0.57, but you have numba 0.56.4 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# woodwork 0.29.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# woodwork 0.29.0 requires scipy>=1.10.0, but you have scipy 1.9.3 which is incompatible.
# ydata-profiling 4.6.4 requires pydantic>=2, but you have pydantic 1.10.14 which is incompatible.
# Successfully installed anyio-3.7.1 faiss-cpu-1.7.3 fastapi-0.88.0 h11-0.12.0 httpcore-0.15.0 httpx-0.23.0 librosa-0.9.1 llvmlite-0.39.0 pydantic-1.10.14 pyworld-0.3.2 rfc3986-1.5.0 scipy-1.12.0 starlette-0.22.0 torchcrepe-0.0.20
# Hit:1 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Get:2 https://packages.cloud.google.com/apt cloud-sdk InRelease [6361 B]
# Get:3 https://packages.cloud.google.com/apt google-fast-socket InRelease [5015 B]
# Hit:4 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1581 B]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:7 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Get:9 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [623 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1474 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1489 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [3593 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3980 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3505 kB]
# Get:15 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1194 kB]
# Get:16 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [3442 kB]
# Fetched 19.5 MB in 2s (8825 kB/s)
#
# The following additional packages will be installed:
#   libaria2-0 libc-ares2 libssh2-1
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2 libssh2-1
# 0 upgraded, 4 newly installed, 0 to remove and 65 not upgraded.
# Need to get 1551 kB of archives.
# After this operation, 6235 kB of additional disk space will be used.
#
# 78Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 114009 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.15.0-1ubuntu0.5_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  6%] [###.......................................................] 8Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.5) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../libssh2-1_1.8.0-2.1ubuntu0.1_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libssh2-1:amd64 (1.8.0-2.1ubuntu0.1) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.35.0-1build1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libaria2-0:amd64 (1.35.0-1build1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.35.0-1build1_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking aria2 (1.35.0-1build1) ...
# 7Progress: [ 47%] [###########################...............................] 8Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.5) ...
# 7Progress: [ 53%] [##############################............................] 87Progress: [ 59%] [##################################........................] 8Setting up libssh2-1:amd64 (1.8.0-2.1ubuntu0.1) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 71%] [########################################..................] 8Setting up libaria2-0:amd64 (1.35.0-1build1) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 82%] [###############################################...........] 8Setting up aria2 (1.35.0-1build1) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 94%] [######################################################....] 8Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.14) ...
#
# 78

# %%
# Загрузка файлов и т.д 
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://bit.ly/45J4v80 -d /kaggle/working/content/rmvpe-ai/pretrained_v2 -o f0D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://bit.ly/45XHOfP -d /kaggle/working/content/rmvpe-ai/pretrained_v2 -o f0G40k.pth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://bit.ly/3L9mNa8 -d /kaggle/working/content/rmvpe-ai -o hubert_base.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://bit.ly/47Yxi9Y -d /kaggle/working/content/rmvpe-ai -o rmvpe.pt
# Out:
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# bf434c|OK  |   242MiB/s|/kaggle/working/content/rmvpe-ai/pretrained_v2/f0D40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 68b2cc|OK  |   192MiB/s|/kaggle/working/content/rmvpe-ai/pretrained_v2/f0G40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 968843|OK  |   292MiB/s|/kaggle/working/content/rmvpe-ai/hubert_base.pt
#
# Status Legend:
# (OK):download completed.
# [#fccec7 162MiB/172MiB(94%) CN:15 DL:303MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# fccec7|OK  |   219MiB/s|/kaggle/working/content/rmvpe-ai/rmvpe.pt
#
# Status Legend:
# (OK):download completed.

# %% [markdown]
# # Download dataset

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.1.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.1.0-py3-none-any.whl (17 kB)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: gdown
# Successfully installed gdown-5.1.0

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1J3DfGQXuux3mfvzpZWtHFy8WQRYN9jjy/view?usp=drive_link -O /kaggle/working/content/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1J3DfGQXuux3mfvzpZWtHFy8WQRYN9jjy
# From (redirected): https://drive.google.com/uc?id=1J3DfGQXuux3mfvzpZWtHFy8WQRYN9jjy&confirm=t&uuid=b3239a9e-4e54-4002-90ee-430a1d72d358
# To: /kaggle/working/content/dataset-vantung-discovery-processed.zip
# 100%|████████████████████████████████████████| 125M/125M [00:01<00:00, 80.6MB/s]

# %%
# !unzip /kaggle/working/content/dataset-vantung-discovery-processed.zip
# Out:
# Archive:  /kaggle/working/content/dataset-vantung-discovery-processed.zip
#   inflating: dataset-vantung-discovery-processed/83Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/78Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/86Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/82Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/87Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/84Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/81Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/88Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/80Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/89Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/79Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/90Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/85Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/65Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/76Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/61Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/72Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/75Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/66Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/69Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/68Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/64Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/74Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/77Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/71Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/67Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/70Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/73Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/48Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/63Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/62Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/54Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/53Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/49Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/58Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/59Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/57Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/46Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/31Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/47Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/32Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/51Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/55Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/30Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/44Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/45Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/38Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/41Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/29Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/43Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/42Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/11Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/35Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/50Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/56Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/37Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/28Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/36Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/39Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/21Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/26Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/23Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/10Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/52Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/34Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/13Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/40Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/33Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/17Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/16Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/15Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/24Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/25Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/12Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/18Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/07Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/19Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/60Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/20Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/02Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/03Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/22Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/27Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/09Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/01Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/05Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/06Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/04Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/14Label_DeepFilterNet3.wav
#   inflating: dataset-vantung-discovery-processed/08Label_DeepFilterNet3.wav

# %% [markdown]
# # Slice normalization

# %%
MODELNAME = "van-tung-v2" 
# !mkdir -p logs/{MODELNAME}
# !touch logs/{MODELNAME}/preprocess.log
#!touch logs/mi-test/filelist.txt
#!touch logs/filelist.txt

# !touch logs/{MODELNAME}/extract_f0_feature.log
#python extract_f0_print.py logs/mi-test $(nproc) pm
#python extract_feature_print.py cpu 1 0 0 logs/braga01 v1

# %%
# @markdown Битрейт выборки
BITRATE = 40000  # @param {type:"integer"}
# @markdown Количество потоков
THREADCOUNT = 8  # @param {type:"integer"}

# Запуск скрипта trainset_preprocess_pipeline_print.py с указанными параметрами
# !python3 trainset_preprocess_pipeline_print.py /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed {BITRATE} {THREADCOUNT} logs/{MODELNAME} True
# Out:
# ['trainset_preprocess_pipeline_print.py', '/kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed', '40000', '8', 'logs/van-tung-v2', 'True']
# start preprocess
# ['trainset_preprocess_pipeline_print.py', '/kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed', '40000', '8', 'logs/van-tung-v2', 'True']
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/01Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/09Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/17Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/25Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/33Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/41Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/49Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/57Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/65Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/73Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/81Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/89Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/02Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/10Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/18Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/26Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/34Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/42Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/50Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/58Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/66Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/74Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/82Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/90Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/03Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/11Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/19Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/27Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/35Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/43Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/51Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/59Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/67Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/75Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/83Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/04Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/12Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/20Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/28Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/36Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/44Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/52Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/60Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/68Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/76Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/84Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/05Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/13Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/21Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/29Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/37Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/45Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/53Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/61Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/69Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/77Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/85Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/06Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/14Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/22Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/30Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/38Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/46Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/54Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/62Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/70Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/78Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/86Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/07Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/15Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/23Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/31Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/39Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/47Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/55Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/63Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/71Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/79Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/87Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/08Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/16Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/24Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/32Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/40Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/48Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/56Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/64Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/72Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/80Label_DeepFilterNet3.wav->Suc.
# /kaggle/working/content/rmvpe-ai/dataset-vantung-discovery-processed/88Label_DeepFilterNet3.wav->Suc.
# end preprocess

# %% [markdown]
# # Preprocessing and Feature Extraction

# %%
# @markdown Количество потоков
THREADCOUNT = 8  # @param {type:"integer"}
# @markdown Алгоритм извлечения высоты тона
ALGO = "rmvpe"  # @param {type:"string"} pm|harvest|crepe|rmvpe

# Запуск скрипта extract_f0_print.py с указанными параметрами
# !python3 extract_f0_print.py logs/{MODELNAME} {THREADCOUNT} {ALGO}

# Запуск скрипта extract_feature_print.py с указанными параметрами
# !python3 extract_feature_print.py cpu 1 0 0 logs/{MODELNAME} v2
# Out:
# ['extract_f0_print.py', 'logs/van-tung-v2', '8', 'rmvpe']
# todo-f0-43
# f0ing,now-0,all-43,-logs/van-tung-v2/1_16k_wavs/0_0.wav
# todo-f0-43
# f0ing,now-0,all-43,-logs/van-tung-v2/1_16k_wavs/0_1.wav
# todo-f0-42
# f0ing,now-0,all-42,-logs/van-tung-v2/1_16k_wavs/0_2.wav
# todo-f0-42
# f0ing,now-0,all-42,-logs/van-tung-v2/1_16k_wavs/0_4.wav
# todo-f0-42
# f0ing,now-0,all-42,-logs/van-tung-v2/1_16k_wavs/10_1.wav
# todo-f0-42
# f0ing,now-0,all-42,-logs/van-tung-v2/1_16k_wavs/10_3.wav
# todo-f0-42
# f0ing,now-0,all-42,-logs/van-tung-v2/1_16k_wavs/10_0.wav
# todo-f0-42
# f0ing,now-0,all-42,-logs/van-tung-v2/1_16k_wavs/10_4.wav
# loading rmvpe model
# loading rmvpe model
# loading rmvpe model
# loading rmvpe model
# loading rmvpe model
# loading rmvpe model
# loading rmvpe model
# loading rmvpe model
# f0ing,now-8,all-42,-logs/van-tung-v2/1_16k_wavs/26_2.wav
# f0ing,now-8,all-42,-logs/van-tung-v2/1_16k_wavs/25_5.wav
# f0ing,now-8,all-42,-logs/van-tung-v2/1_16k_wavs/25_3.wav
# f0ing,now-8,all-43,-logs/van-tung-v2/1_16k_wavs/24_5.wav
# f0ing,now-8,all-42,-logs/van-tung-v2/1_16k_wavs/25_1.wav
# f0ing,now-8,all-42,-logs/van-tung-v2/1_16k_wavs/26_1.wav
# f0ing,now-8,all-42,-logs/van-tung-v2/1_16k_wavs/26_0.wav
# f0ing,now-8,all-43,-logs/van-tung-v2/1_16k_wavs/25_0.wav
# f0ing,now-16,all-42,-logs/van-tung-v2/1_16k_wavs/41_3.wav
# f0ing,now-16,all-42,-logs/van-tung-v2/1_16k_wavs/41_1.wav
# f0ing,now-16,all-43,-logs/van-tung-v2/1_16k_wavs/40_1.wav
# f0ing,now-16,all-42,-logs/van-tung-v2/1_16k_wavs/42_2.wav
# f0ing,now-16,all-42,-logs/van-tung-v2/1_16k_wavs/40_4.wav
# f0ing,now-16,all-42,-logs/van-tung-v2/1_16k_wavs/42_1.wav
# f0ing,now-16,all-42,-logs/van-tung-v2/1_16k_wavs/41_4.wav
# f0ing,now-16,all-43,-logs/van-tung-v2/1_16k_wavs/40_2.wav
# f0ing,now-24,all-42,-logs/van-tung-v2/1_16k_wavs/57_5.wav
# f0ing,now-24,all-43,-logs/van-tung-v2/1_16k_wavs/56_5.wav
# f0ing,now-24,all-42,-logs/van-tung-v2/1_16k_wavs/57_4.wav
# f0ing,now-24,all-42,-logs/van-tung-v2/1_16k_wavs/58_3.wav
# f0ing,now-24,all-42,-logs/van-tung-v2/1_16k_wavs/58_0.wav
# f0ing,now-24,all-43,-logs/van-tung-v2/1_16k_wavs/57_0.wav
# f0ing,now-24,all-42,-logs/van-tung-v2/1_16k_wavs/57_2.wav
# f0ing,now-32,all-43,-logs/van-tung-v2/1_16k_wavs/71_5.wav
# f0ing,now-32,all-42,-logs/van-tung-v2/1_16k_wavs/72_5.wav
# f0ing,now-24,all-42,-logs/van-tung-v2/1_16k_wavs/58_2.wav
# f0ing,now-32,all-42,-logs/van-tung-v2/1_16k_wavs/73_5.wav
# f0ing,now-32,all-42,-logs/van-tung-v2/1_16k_wavs/72_4.wav
# f0ing,now-32,all-43,-logs/van-tung-v2/1_16k_wavs/72_1.wav
# f0ing,now-40,all-42,-logs/van-tung-v2/1_16k_wavs/88_4.wav
# f0ing,now-32,all-42,-logs/van-tung-v2/1_16k_wavs/72_2.wav
# f0ing,now-32,all-42,-logs/van-tung-v2/1_16k_wavs/73_1.wav
# f0ing,now-40,all-43,-logs/van-tung-v2/1_16k_wavs/87_2.wav
# f0ing,now-32,all-42,-logs/van-tung-v2/1_16k_wavs/73_3.wav
# f0ing,now-40,all-42,-logs/van-tung-v2/1_16k_wavs/88_2.wav
# f0ing,now-40,all-42,-logs/van-tung-v2/1_16k_wavs/89_1.wav
# f0ing,now-40,all-42,-logs/van-tung-v2/1_16k_wavs/88_0.wav
# f0ing,now-40,all-43,-logs/van-tung-v2/1_16k_wavs/87_4.wav
# f0fail-41-logs/van-tung-v2/1_16k_wavs/89_5.wav-Traceback (most recent call last):
#   File "/kaggle/working/content/rmvpe-ai/extract_f0_print.py", line 117, in go
#     featur_pit = self.compute_f0(inp_path, f0_method)
#   File "/kaggle/working/content/rmvpe-ai/extract_f0_print.py", line 83, in compute_f0
#     f0 = self.model_rmvpe.infer_from_audio(x, thred=0.03)
#   File "/kaggle/working/content/rmvpe-ai/lib/rmvpe.py", line 374, in infer_from_audio
#     hidden = self.mel2hidden(mel)
#   File "/kaggle/working/content/rmvpe-ai/lib/rmvpe.py", line 354, in mel2hidden
#     mel = F.pad(
# RuntimeError: Argument #4: Padding size should be less than the corresponding input dimension, but got: padding (0, 20) at dimension 2 of input [1, 128, 12]
#
# f0ing,now-40,all-42,-logs/van-tung-v2/1_16k_wavs/88_5.wav
# f0ing,now-40,all-42,-logs/van-tung-v2/1_16k_wavs/89_0.wav
# 2024-04-02 05:31:14.543246: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:31:14.543406: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:31:14.793522: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ['extract_feature_print.py', 'cpu', '1', '0', '0', 'logs/van-tung-v2', 'v2']
# logs/van-tung-v2
# load model(s) from hubert_base.pt
# /opt/conda/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# move model to cuda
# all-feature-338
# now-338,all-0,0_0.wav,(149, 768)
# now-338,all-33,17_5.wav,(64, 768)
# now-338,all-66,25_1.wav,(149, 768)
# now-338,all-99,32_2.wav,(149, 768)
# now-338,all-132,41_3.wav,(122, 768)
# now-338,all-165,4_1.wav,(149, 768)
# now-338,all-198,58_2.wav,(46, 768)
# now-338,all-231,66_0.wav,(149, 768)
# now-338,all-264,74_0.wav,(149, 768)
# now-338,all-297,81_5.wav,(38, 768)
# now-338,all-330,89_5.wav,(5, 768)
# all-feature-done

# %%
# @markdown Частота дискретизации модели
MODELSAMPLE = "40k"  # @param {type:"string"}

# Запуск скрипта create_filelist_print.py с указанными параметрами
# !python3 create_filelist_print.py {MODELNAME} v2 True {MODELSAMPLE} 0
# Out:
# write filelist done

# %% [markdown]
# # Train indexing

# %%
# Запуск скрипта train_index_print.py с указанным названием модели
# !python3 train_index_print.py {MODELNAME} v2
# Out:
# (41153, 768),1055
# training
# adding
# 成功构建索引，added_IVF1055_Flat_nprobe_1_van-tung-v2_v2.index
# OK

# %% [markdown]
# # Training

# %%
import threading
import os
import time

# @markdown Используемая GPU (Значение 0,1 две видокарты от GPU T4 X2)
USEGPU = "0,1"  # @param {type:"string"}
# @markdown Размер пакета (batch size)
BATCHSIZE = 8  # @param {type:"integer"}
# @markdown КОЛ-ВО ЭПОХ
MODELEPOCH = 1000  # @param {type:"integer"}
# @markdown Интервал сохранения модели (через сколько эпох)
EPOCHSAVE = 100  # @param {type:"integer"}
# @markdown Частота дискретизации модели
MODELSAMPLE = "40k"  # @param {type:"string"}
# @markdown Кэшировать данные обучающего набора (1 - Да, 0 - Нет)
CACHEDATA = 0  # @param {type:"integer"}
# @markdown Сохранять только последний файл весов (1 - Да, 0 - Нет)
ONLYLATEST = 0  # @param {type:"integer"} 

def train_model():
    os.system(f"python3 train_nsf_sim_cache_sid_load_pretrain.py -e {MODELNAME} -sr {MODELSAMPLE} -f0 1 -bs {BATCHSIZE} -g {USEGPU} -te {MODELEPOCH} -se {EPOCHSAVE} -pg pretrained_v2/f0G{MODELSAMPLE}.pth -pd pretrained_v2/f0D{MODELSAMPLE}.pth -l {ONLYLATEST} -c {CACHEDATA} -sw 1 -v v2")

def tail_log():
    log_file = "/kaggle/working/content/rmvpe-ai/logs/" + MODELNAME + "/train.log"
    last_epoch = None
    last_position = 0
    training_started = False
    while True:
        if os.path.exists(log_file):
            with open(log_file, 'r') as file:
                file.seek(last_position)
                lines = file.readlines()
                last_position = file.tell()
                for line in lines:
                    if "Epoch:" in line:
                        current_epoch = int(line.split("Epoch:")[1].split()[0])
                        if not training_started and current_epoch == 1:
                            print("НАЧАЛАСЬ ТРЕНИРОВКА ГОЛОСОВОЙ МОДЕЛИ")
                            training_started = True
                        if current_epoch != last_epoch:
                            print(line.strip().replace(f"Epoch: {current_epoch}", f"Epoch: {current_epoch} \ {MODELEPOCH}"))
                            last_epoch = current_epoch
                        if current_epoch % EPOCHSAVE == 0:
                            print(f"Сохранено {current_epoch} Эпох")
                        if current_epoch == MODELEPOCH:
                            check_model_file()
        time.sleep(10)  # Проверяем файл каждые 10 секунд

def check_model_file():
    pth_file = f"/kaggle/working/content/rmvpe-ai/weights/{MODELNAME}.pth"
    
    if os.path.exists(pth_file):
        print(f'Модель "{MODELNAME}" Готова!')
        raise SystemExit("Завершение выполнения ячейки")
    else:
        print(f'Файл модели "{MODELNAME}" не найден.')

# Create threads
train_thread = threading.Thread(target=train_model)
tail_thread = threading.Thread(target=tail_log)

# Start threads
train_thread.start()
tail_thread.start()

# Join threads
train_thread.join()
tail_thread.join()
# Out:
# 2024-04-02 05:32:26.766095: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:32:26.766154: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:32:26.767876: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-02 05:32:34.310530: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:32:34.310576: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:32:34.312133: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-02 05:32:34.632130: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:32:34.632194: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:32:34.633935: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# /opt/conda/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# <All keys matched successfully>
# gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# <All keys matched successfully>
# 2024-04-02 05:32:45.625137: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:32:45.625138: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:32:45.625238: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:32:45.625239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:32:45.626890: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-02 05:32:45.626923: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-02 05:32:52.912361: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:32:52.912414: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:32:52.913902: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-02 05:32:52.984652: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:32:52.984701: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:32:52.986215: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-02 05:33:00.044049: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:33:00.044115: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:33:00.045824: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-02 05:33:00.109648: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:33:00.109703: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:33:00.111323: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-02 05:33:07.645076: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:33:07.645147: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:33:07.646774: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-02 05:33:07.789675: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 05:33:07.789724: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 05:33:07.791258: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:650: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/SpectralOps.cpp:863.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:650: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/SpectralOps.cpp:863.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:650: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/SpectralOps.cpp:863.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:650: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/SpectralOps.cpp:863.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:650: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/SpectralOps.cpp:863.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:650: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/SpectralOps.cpp:863.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:650: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/SpectralOps.cpp:863.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:650: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/SpectralOps.cpp:863.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:650: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/SpectralOps.cpp:863.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:650: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/SpectralOps.cpp:863.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/autograd/__init__.py:251: UserWarning: Grad strides do not match bucket view strides. This may indicate grad was not created according to the gradient layout contract, or that the param's strides changed since DDP was constructed.  This is not an error, but may impair performance.
# grad.sizes() = [64, 1, 4], strides() = [4, 1, 1]
# bucket_view.sizes() = [64, 1, 4], strides() = [4, 4, 1] (Triggered internally at /usr/local/src/pytorch/torch/csrc/distributed/c10d/reducer.cpp:320.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /opt/conda/lib/python3.10/site-packages/torch/autograd/__init__.py:251: UserWarning: Grad strides do not match bucket view strides. This may indicate grad was not created according to the gradient layout contract, or that the param's strides changed since DDP was constructed.  This is not an error, but may impair performance.
# grad.sizes() = [64, 1, 4], strides() = [4, 1, 1]
# bucket_view.sizes() = [64, 1, 4], strides() = [4, 4, 1] (Triggered internally at /usr/local/src/pytorch/torch/csrc/distributed/c10d/reducer.cpp:320.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# НАЧАЛАСЬ ТРЕНИРОВКА ГОЛОСОВОЙ МОДЕЛИ
# 2024-04-02 05:33:21,312	van-tung-v2	INFO	Train Epoch: 1 \ 1000 [0%]
# 2024-04-02 05:33:49,956	van-tung-v2	INFO	====> Epoch: 2 \ 1000 [2024-04-02 05:33:49] | (0:00:13.619528)
# 2024-04-02 05:34:03,491	van-tung-v2	INFO	====> Epoch: 3 \ 1000 [2024-04-02 05:34:03] | (0:00:13.525302)
# 2024-04-02 05:34:17,085	van-tung-v2	INFO	====> Epoch: 4 \ 1000 [2024-04-02 05:34:17] | (0:00:13.585196)
# 2024-04-02 05:34:30,531	van-tung-v2	INFO	====> Epoch: 5 \ 1000 [2024-04-02 05:34:30] | (0:00:13.435684)
# 2024-04-02 05:34:44,302	van-tung-v2	INFO	====> Epoch: 6 \ 1000 [2024-04-02 05:34:44] | (0:00:13.760694)
# 2024-04-02 05:34:57,713	van-tung-v2	INFO	====> Epoch: 7 \ 1000 [2024-04-02 05:34:57] | (0:00:13.401541)
# 2024-04-02 05:35:11,396	van-tung-v2	INFO	====> Epoch: 8 \ 1000 [2024-04-02 05:35:11] | (0:00:13.674982)
# 2024-04-02 05:35:24,861	van-tung-v2	INFO	====> Epoch: 9 \ 1000 [2024-04-02 05:35:24] | (0:00:13.445063)
# 2024-04-02 05:35:38,339	van-tung-v2	INFO	====> Epoch: 10 \ 1000 [2024-04-02 05:35:38] | (0:00:13.468225)
# 2024-04-02 09:21:13,457	van-tung-v2	INFO	====> Epoch: 992 \ 1000 [2024-04-02 09:21:13] | (0:00:13.800243)
# 2024-04-02 09:21:26,907	van-tung-v2	INFO	====> Epoch: 993 \ 1000 [2024-04-02 09:21:26] | (0:00:13.440714)
# 2024-04-02 09:21:41,397	van-tung-v2	INFO	====> Epoch: 994 \ 1000 [2024-04-02 09:21:41] | (0:00:14.480711)
# 2024-04-02 09:21:54,844	van-tung-v2	INFO	====> Epoch: 995 \ 1000 [2024-04-02 09:21:54] | (0:00:13.437301)
# 2024-04-02 09:22:09,087	van-tung-v2	INFO	====> Epoch: 996 \ 1000 [2024-04-02 09:22:09] | (0:00:14.232429)
# 2024-04-02 09:22:22,523	van-tung-v2	INFO	====> Epoch: 997 \ 1000 [2024-04-02 09:22:22] | (0:00:13.391073)
# 2024-04-02 09:22:36,547	van-tung-v2	INFO	====> Epoch: 998 \ 1000 [2024-04-02 09:22:36] | (0:00:14.014010)
# 2024-04-02 09:22:51,677	van-tung-v2	INFO	====> Epoch: 999 \ 1000 [2024-04-02 09:22:51] | (0:00:15.118902)
# Process Process-2:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/kaggle/working/content/rmvpe-ai/train_nsf_sim_cache_sid_load_pretrain.py", line 242, in run
#     train_and_evaluate(
#   File "/kaggle/working/content/rmvpe-ai/train_nsf_sim_cache_sid_load_pretrain.py", line 441, in train_and_evaluate
#     scaler.scale(loss_disc).backward()
#   File "/opt/conda/lib/python3.10/site-packages/torch/_tensor.py", line 492, in backward
#     torch.autograd.backward(
#   File "/opt/conda/lib/python3.10/site-packages/torch/autograd/__init__.py", line 251, in backward
#     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# RuntimeError: [/usr/local/src/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:534] Connection closed by peer [172.19.2.2]:29105
# /opt/conda/lib/python3.10/multiprocessing/resource_tracker.py:224: UserWarning: resource_tracker: There appear to be 20 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# 2024-04-02 09:23:08,324	van-tung-v2	INFO	====> Epoch: 1000 \ 1000 [2024-04-02 09:23:08] | (0:00:16.634709)
# Сохранено 1000 Эпох
# Модель "van-tung-v2" Готова!

# %% [markdown]
# ## **Имя Модели (Заменить)**

# %%
import os
import zipfile
import glob

# Задайте имя ZIP-архива здесь:
ZIP_NAME = "van-tung_v1.zip"

def check_and_zip_files(model_name, zip_name=ZIP_NAME):
    base_name = os.path.splitext(zip_name)[0]  # Убираем расширение .zip
    
    # Поиск файла .index с учетом возможного различного числа после IVF
    index_files = glob.glob(f"/kaggle/working/content/rmvpe-ai/logs/{model_name}/added_IVF*_Flat_nprobe_1_{model_name}_v2.index")
    if not index_files:
        return False
    index_file_path = index_files[0]
    index_file_name = os.path.basename(index_file_path).replace(model_name, base_name)
    pth_file = f"/kaggle/working/content/rmvpe-ai/weights/{model_name}.pth"
    
    if os.path.exists(index_file_path) and os.path.exists(pth_file):
        with zipfile.ZipFile(f"/kaggle/working/{zip_name}", 'w') as zipf:
            zipf.write(index_file_path, index_file_name)
            zipf.write(pth_file, f"{base_name}.pth")
        return True
    return False

# После завершения тренировки:
if check_and_zip_files(MODELNAME):
    print(f"Файлы модели упакованы в {ZIP_NAME}")
else:
    print("Не удалось найти файлы модели.")
# Out:
# Файлы модели упакованы в van-tung_v1.zip
